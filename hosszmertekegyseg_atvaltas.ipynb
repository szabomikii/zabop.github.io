# %%
import numpy as np
import random

# %%
# !pwd
# Out:
# /home/pal

# %%
szamlist = np.random.randint(0,100,2)

# %%
mertekegysegek = {1000:'km', 1:' m', 0.1:'dm', 0.01:'cm', 0.001:'mm'}

# %%
szorzo1, mertekegyseg1 = random.choice(list(mertekegysegek.items()))
szorzo2, mertekegyseg2 = random.choice(list(mertekegysegek.items()))
szorzo3, mertekegyseg3 = random.choice(list(mertekegysegek.items()))

# %%
eredmeny = np.round((szamlist[0]*szorzo1 + szamlist[1]*szorzo2) / szorzo3, 3)

# %%
print(szamlist[0],mertekegyseg1,' + ',szamlist[1],mertekegyseg2,' = ...... ' + mertekegyseg3+ '\t\t\t\t\t\t\t(',eredmeny,')')
# Out:
# 77 km  +  60  m  = ...... mm							( 77060000.0 )

# %%
def feladatcsinalo(mennyit):
    for ennyediketcsinalod in range(mennyit):
        
        if ennyediketcsinalod % 20 == 0 and ennyediketcsinalod !=0 : print('\nmár ennyit megcsináltál:',ennyediketcsinalod)
        
        szamlist = np.random.randint(0,100,2)
        szorzo1, mertekegyseg1 = random.choice(list(mertekegysegek.items()))
        szorzo2, mertekegyseg2 = random.choice(list(mertekegysegek.items()))
        szorzo3, mertekegyseg3 = random.choice(list(mertekegysegek.items()))
        eredmeny = np.round((szamlist[0]*szorzo1 + szamlist[1]*szorzo2) / szorzo3, 3)
        print(szamlist[0],mertekegyseg1,' + ',szamlist[1],mertekegyseg2,' = ... ' + mertekegyseg3,'\t\t\t\t\t\t\t\t(',eredmeny,')')        
print('ez összesen 1000 volt')
# Out:
# ez összesen 1000 volt

# %%
feladatcsinalo(1000)
# Out:
# 83 dm  +  49 mm  = ... km 								( 0.008 )
# 43 dm  +  75  m  = ... km 								( 0.079 )
# 72 dm  +  81 km  = ... mm 								( 81007200.0 )
# 92 km  +  32  m  = ...  m 								( 92032.0 )
# 13 mm  +  96 cm  = ... dm 								( 9.73 )
# 87 mm  +  65 dm  = ... cm 								( 658.7 )
# 95  m  +  46  m  = ...  m 								( 141.0 )
# 56 mm  +  31  m  = ... dm 								( 310.56 )
# 68 dm  +  73 km  = ... mm 								( 73006800.0 )
# 96 cm  +  6 km  = ... dm 								( 60009.6 )
# 35 dm  +  3 cm  = ... cm 								( 353.0 )
# 61 mm  +  39 km  = ... cm 								( 3900006.1 )
# 23 mm  +  17 mm  = ... cm 								( 4.0 )
# 25 dm  +  4 km  = ... mm 								( 4002500.0 )
# 68 cm  +  58 dm  = ...  m 								( 6.48 )
# 60 mm  +  29 cm  = ... km 								( 0.0 )
# 80 km  +  96  m  = ... cm 								( 8009600.0 )
# 84 cm  +  59 km  = ... cm 								( 5900084.0 )
# 0  m  +  98 mm  = ... mm 								( 98.0 )
# 21 cm  +  1 mm  = ... dm 								( 2.11 )
#
# már ennyit megcsináltál: 20
# ...
