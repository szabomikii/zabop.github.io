# %%
import glob as g
import pyke
import scipy
from photutils import detect_threshold, detect_sources, deblend_sources
import numpy as np
from astropy.stats import gaussian_fwhm_to_sigma
from astropy.convolution import Gaussian2DKernel
from k2sc.standalone import k2sc_lc
from astropy.io import fits
import lightkurve as lk
from sklearn.cluster import DBSCAN
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
class star:
    
    def __init__(self, ID):
        self.ID = ID
        self.fits_image_filename=self.ID[:-5]+"-kepextract.fits"
        
    def kepextract(self):
        pyke.kepextract(self.ID,maskfile='ALL',psfcentroid=True,overwrite=True)
        with fits.open(self.fits_image_filename) as hdul:
            data=hdul[1].data
        self.psfc1=data['PSF_CENTR1']
        self.psfc2=data['PSF_CENTR2']
        
        newpsfcP=[]
        for index, line in enumerate(self.psfc1): newpsfcP.append([self.psfc1[index],self.psfc2[index]])
        self.newpsfc=np.asarray(newpsfcP)

    def tpfs(self):
        self.tpf=lk.targetpixelfile.KeplerTargetPixelFile(self.ID)
        
    def clustering(self):
        db = DBSCAN(eps=0.3, min_samples=10).fit(self.newpsfc)
        self.core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
        self.core_samples_mask[db.core_sample_indices_] = True
        
    def apcalc(self):
        
        self.countergrid_all=np.asarray([[0]*len(self.tpf.flux[0][0]) for n in range(len(self.tpf.flux[0]))])
        
        for i in range(len(self.tpf.flux)):
            if i in np.where(self.core_samples_mask==True)[0]:
                tpfdata=self.tpf.flux[i]

                threshold = detect_threshold(tpfdata, snr=1.8)
                sigma = 3.0 * gaussian_fwhm_to_sigma    # FWHM = 3.
                kernel = Gaussian2DKernel(sigma, x_size=1, y_size=1)
                kernel.normalize()
                segm = detect_sources(tpfdata, threshold, npixels=1, filter_kernel=kernel)
                segm_deblend = deblend_sources(tpfdata, segm, npixels=5, filter_kernel=kernel)

                apx=[];apy=[]
                for x in range(len(segm.data)):
                    for y in range(len(segm.data[0])):
                        if segm.data[x][y]!=0:
                            apx.append(x)
                            apy.append(y)

                self.countergrid_all += segm.data

        limitc=(self.countergrid_all>len(self.tpf.flux)/2.5)
        
        self.labelgrid, self.num_features = scipy.ndimage.measurements.label(limitc)      
        
        
    def getlargestap(self):
        
        sizeoffeature=0
        self.largestfeature=0
        
        self.featuresizelist=[]
        
        for i in range(self.num_features):
        
            sizeofthis=len(np.where(self.labelgrid == (i+1))[0])
            
            self.featuresizelist.append(sizeofthis)
            
            if sizeofthis>sizeoffeature:
                
                sizeoffeature=sizeofthis
                self.largestfeature=(i+1)

        
    def make_lc(self):
        
        lc = self.tpf.to_lightcurve(aperture_mask=(self.labelgrid==(self.largestfeature)).astype(bool)) # load some data either as a tpf or just straight up as a lightcurve
        lc.primary_header = self.tpf.hdu[0].header
        lc.data_header = self.tpf.hdu[1].header
        lc.pos_corr1 = self.tpf.hdu[1].data['POS_CORR1'][self.tpf.quality_mask]
        lc.pos_corr2 = self.tpf.hdu[1].data['POS_CORR2'][self.tpf.quality_mask]
        lc.__class__ = k2sc_lc
        lc.k2sc()
        self.ourlc=lc
        
    def writeout(self):
        
        fout=open(self.ID+"OOPoutII",'w')
        fout.write(str(self.ID)+"\n")
        fout.write("size_of_found_features:\n")
        for each in self.featuresizelist: fout.write(str(each)+" ")
        fout.write("\n")
        fout.write("lc.time lc.corr_flux\n")
        for index, each in enumerate(self.ourlc.time):
            fout.write(str(each)+" "+str(self.ourlc.corr_flux[index])+"\n")
        fout.close()

# %%
OURSTARS=g.glob('/home/pal/konkoly/automaticaperture/sourcefits/ktwo*targ.fits')

# %%
for EACH in OURSTARS:
    ourstar=star(ID=EACH)
    ourstar.kepextract()
    ourstar.tpfs()
    ourstar.clustering()
    ourstar.apcalc()
    ourstar.getlargestap()
    ourstar.make_lc()
    ourstar.writeout()
# Out:
# Aperture photometry: 100%|██████████| 3561/3561 [00:06<00:00, 565.74it/s]
# Computing moments: 100%|██████████| 3561/3561 [00:01<00:00, 2977.29it/s]
# PSF centroiding: 100%|██████████| 3561/3561 [00:10<00:00, 339.23it/s]
# /home/pal/.local/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py:165: RuntimeWarning: invalid value encountered in greater
#   _filtered_data.mask |= _filtered_data > max_value
# /home/pal/.local/lib/python3.6/site-packages/astropy/stats/sigma_clipping.py:166: RuntimeWarning: invalid value encountered in less
#   _filtered_data.mask |= _filtered_data < min_value
# /home/pal/.local/lib/python3.6/site-packages/photutils/segmentation/detect.py:128: RuntimeWarning: invalid value encountered in greater
#   check_normalization=True) > threshold)
# Using default splits [2344] for campaign 5
# Starting initial outlier detection
#   Flagged 0 ( 0.0%) outliers.
# Starting Lomb-Scargle period search
#   Using SqrExp position kernel
#   Found periodicity p =    0.58 (fap 0.0000e+00 < 1e-50), will use a quasiperiodic kernel
# Starting global hyperparameter optimisation using DE
#   DE iteration %3i -ln(L) %4.1f 0 1228.7539455813248
#   DE iteration %3i -ln(L) %4.1f 1 1228.7539455813248
#   DE iteration %3i -ln(L) %4.1f 2 -839.1827263852257
#   DE iteration %3i -ln(L) %4.1f 3 -839.1827263852257
#   DE iteration %3i -ln(L) %4.1f 4 -938.3154560487983
#   DE iteration %3i -ln(L) %4.1f 5 -1087.6615982525293
#   DE iteration %3i -ln(L) %4.1f 6 -1087.6615982525293
#   DE iteration %3i -ln(L) %4.1f 7 -1087.6615982525293
#   DE iteration %3i -ln(L) %4.1f 8 -1087.6615982525293
#   DE iteration %3i -ln(L) %4.1f 9 -1087.6615982525293
#   DE iteration %3i -ln(L) %4.1f 10 -1115.8910053855836
#   DE iteration %3i -ln(L) %4.1f 11 -1115.8910053855836
#   DE iteration %3i -ln(L) %4.1f 12 -1125.479009334657
#   DE iteration %3i -ln(L) %4.1f 13 -1125.479009334657
#   DE iteration %3i -ln(L) %4.1f 14 -1125.479009334657
#   DE iteration %3i -ln(L) %4.1f 15 -1233.2767294643756
#   DE iteration %3i -ln(L) %4.1f 16 -1233.2767294643756
#   DE iteration %3i -ln(L) %4.1f 17 -1233.2767294643756
#   DE iteration %3i -ln(L) %4.1f 18 -1233.2767294643756
#   DE iteration %3i -ln(L) %4.1f 19 -1288.8166406254873
#   DE iteration %3i -ln(L) %4.1f 20 -1288.8166406254873
#   DE iteration %3i -ln(L) %4.1f 21 -1368.7785655463574
#   DE iteration %3i -ln(L) %4.1f 22 -1368.7785655463574
#   DE iteration %3i -ln(L) %4.1f 23 -1368.7785655463574
#   DE iteration %3i -ln(L) %4.1f 24 -1434.4462733036241
#   DE iteration %3i -ln(L) %4.1f 25 -1447.1676268853048
#   DE iteration %3i -ln(L) %4.1f 26 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 27 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 28 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 29 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 30 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 31 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 32 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 33 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 34 -1591.6923611753016
#   DE iteration %3i -ln(L) %4.1f 35 -1594.6656811225512
#   DE iteration %3i -ln(L) %4.1f 36 -1594.6656811225512
#   DE iteration %3i -ln(L) %4.1f 37 -1625.4681559773312
#   DE iteration %3i -ln(L) %4.1f 38 -1625.4681559773312
#   DE iteration %3i -ln(L) %4.1f 39 -1625.4681559773312
#   DE iteration %3i -ln(L) %4.1f 40 -1625.4681559773312
#   DE iteration %3i -ln(L) %4.1f 41 -1696.3403472690563
#   DE iteration %3i -ln(L) %4.1f 42 -1696.3403472690563
#   DE iteration %3i -ln(L) %4.1f 43 -1696.3403472690563
#   DE iteration %3i -ln(L) %4.1f 44 -1709.2138258456491
#   DE iteration %3i -ln(L) %4.1f 45 -1709.2138258456491
#   DE iteration %3i -ln(L) %4.1f 46 -1710.732472059946
#   DE finished in %i seconds 300.34855484962463
#   DE minimum found at: %s [-1.431e+00  3.874e-02  5.820e-01  1.580e-03 -2.473e+00  1.100e-01  3.995e+01 -1.238e+00]
#   DE -ln(L) %4.1f -1710.732472059946
# Starting local hyperparameter optimisation
#   Local minimum found at: %s [-1.847e+00  1.038e-02  5.822e-01  2.165e-05 -1.636e+00  6.956e-10
#   7.398e-05 -1.473e+00]
# Starting final outlier detection
#   %5i too high 80
#   %5i too low 54
#   %5i not finite 0
# Computing time and position trends
# /home/pal/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: ResourceWarning: unclosed file <_io.FileIO name='/home/pal/konkoly/automaticaperture/sourcefits/ktwo212412494-c06_lpd-targ.fits' mode='rb' closefd=True>
#
# Aperture photometry:   0%|          | 0/3561 [00:00<?, ?it/s]
#   CDPP - raw - %6.3f 93650.00587904525
#   CDPP - position component removed - %6.3f 92759.60528357327
#   CDPP - full reduction - %6.3f 2315.5004753152775
# Detrending time %6.3f 343.50878047943115
# Aperture photometry: 100%|██████████| 3561/3561 [00:06<00:00, 563.98it/s]
# Computing moments: 100%|██████████| 3561/3561 [00:01<00:00, 3156.28it/s]
# PSF centroiding: 100%|██████████| 3561/3561 [00:10<00:00, 339.67it/s]
# /home/pal/.local/lib/python3.6/site-packages/numpy/ma/core.py:3042: ResourceWarning: unclosed file <_io.FileIO name='/home/pal/konkoly/automaticaperture/sourcefits/ktwo212412494-c06_lpd-targ.fits' mode='rb' closefd=True>
#   m = reduce(mask_or, [getmaskarray(arg) for arg in input_args])
# Using default splits [2344] for campaign 5
# Starting initial outlier detection
#   Flagged 0 ( 0.0%) outliers.
# Starting Lomb-Scargle period search
#   Using SqrExp position kernel
#   Found periodicity p =    0.32 (fap 0.0000e+00 < 1e-50), will use a quasiperiodic kernel
# Starting global hyperparameter optimisation using DE
#   DE iteration %3i -ln(L) %4.1f 0 847.8419818980956
#   DE iteration %3i -ln(L) %4.1f 1 -610.5782340315551
#   DE iteration %3i -ln(L) %4.1f 2 -1237.460404720246
#   DE iteration %3i -ln(L) %4.1f 3 -1237.460404720246
#   DE iteration %3i -ln(L) %4.1f 4 -1494.555573069934
#   DE iteration %3i -ln(L) %4.1f 5 -1494.555573069934
#   DE iteration %3i -ln(L) %4.1f 6 -1520.7159326543247
#   DE iteration %3i -ln(L) %4.1f 7 -1534.511801482377
#   DE iteration %3i -ln(L) %4.1f 8 -1678.25414487034
#   DE iteration %3i -ln(L) %4.1f 9 -1678.25414487034
#   DE iteration %3i -ln(L) %4.1f 10 -1678.25414487034
#   DE iteration %3i -ln(L) %4.1f 11 -1678.25414487034
#   DE iteration %3i -ln(L) %4.1f 12 -1678.25414487034
#   DE iteration %3i -ln(L) %4.1f 13 -1741.7296005963992
#   DE iteration %3i -ln(L) %4.1f 14 -1741.7296005963992
#   DE iteration %3i -ln(L) %4.1f 15 -1741.7296005963992
#   DE iteration %3i -ln(L) %4.1f 16 -1741.7296005963992
#   DE iteration %3i -ln(L) %4.1f 17 -1815.6435834155202
#   DE iteration %3i -ln(L) %4.1f 18 -1834.711369605336
#   DE iteration %3i -ln(L) %4.1f 19 -1889.137048804873
#   DE iteration %3i -ln(L) %4.1f 20 -1889.137048804873
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-d056f5e1117a> in <module>
#       6     ourstar.apcalc()
#       7     ourstar.getlargestap()
# ----> 8     ourstar.make_lc()
#       9     ourstar.writeout()
#
# <ipython-input-22-aa9a7a8f9ea5> in make_lc(self)
#      80         lc.pos_corr2 = self.tpf.hdu[1].data['POS_CORR2'][self.tpf.quality_mask]
#      81         lc.__class__ = k2sc_lc
# ---> 82         lc.k2sc()
#      83         self.ourlc=lc
#      84
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/standalone.py in k2sc(self, **kwargs)
#     303     def k2sc(self,**kwargs):
#     304         dataset = self.get_k2data()
# --> 305         results = detrend(dataset,**kwargs) # see keyword arguments from detrend above
#     306         self.tr_position = results.tr_position
#     307         self.tr_time = results.tr_time
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/standalone.py in detrend(dataset, campaign, splits, quiet, save_dir, seed, flux_type, default_position_kernel, kernel, kernel_period, p_mask_center, p_mask_period, p_mask_duration, tr_nrandom, tr_nblocks, tr_bspan, de_npop, de_niter, de_max_time, ls_max_fap, ls_min_period, ls_max_period, outlier_sigma, outlier_mwidth)
#     195             print('Starting global hyperparameter optimisation using DE')
#     196             tstart_de = time()
# --> 197             for i,r in enumerate(de(de_niter)):
#     198                 print('  DE iteration %3i -ln(L) %4.1f', i, de.minimum_value)
#     199                 tcur_de = time()
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/de.py in __call__(self, ngen)
#     108                 u[ri] = v[ri].copy()
#     109
# --> 110                 ufit = self.m * self.minfun(u)
#     111
#     112                 if ufit < self._fitness[i]:
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/detrender.py in neglnposterior(self, pv, training)
#      56         ds = self.tr_data if training else self.data
#      57         try:
# ---> 58             lnlike = self.gp.lnlikelihood(pv, ds.masked_normalised_flux, ds.masked_inputs)
#      59             return -(self.kernel.ln_prior(pv) + lnlike)
#      60         except LinAlgError:
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/gp.py in lnlikelihood(self, pv, y, x)
#     129
#     130     def lnlikelihood(self, pv, y=None, x=None):
# --> 131         self.compute(x, pv)
#     132         self._compute_alpha(y)
#     133         return -(log(diag(self._L[0])).sum() + 0.5 * dot(y,self._alpha))
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/gp.py in compute(self, x, pv)
#      80
#      81         if self.is_dirty:
# ---> 82             self._K0 = self._covariance_matrix(self._x, None, separate=False, add_wn=False)
#      83             self._K  = self._K0 + self.kernel._pm[-1]**2 * identity(self._K0.shape[0])
#      84             self._L  = sla.cho_factor(self._K)
#
# ~/.local/lib/python3.6/site-packages/K2SC-1.0-py3.6.egg/k2sc/gp.py in _covariance_matrix(self, x1, x2, separate, add_wn)
#     111     def _covariance_matrix(self, x1, x2=None, separate=False, add_wn=False):
#     112         K1 = self.kernel._k1.get_value(x1, x2)
# --> 113         K2 = self.kernel._k2.get_value(x1, x2)
#     114
#     115         x2 = x2 if x2 is not None else x1
#
# ~/.local/lib/python3.6/site-packages/george/kernels.py in get_value(self, x1, x2, diag)
#     107                 return self.kernel.value_diagonal(x1, x1)
#     108             else:
# --> 109                 return self.kernel.value_symmetric(x1)
#     110         x2 = np.ascontiguousarray(x2, dtype=np.float64)
#     111         if diag:
#
# KeyboardInterrupt:
